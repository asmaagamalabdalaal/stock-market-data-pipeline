# %%
s3_path = "s3://travel-analytics-bronze/mutualfund_etfs/dim_etfsprices/etfsprices.csv"

df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(s3_path)
)

df.display()

# %%
df.write \
  .mode("overwrite") \
  .saveAsTable("finance_analytics.etfsprices")
