# %%
s3_path = "s3://travel-analytics-bronze/mutualfund_etfs/dim_statistics/statistics.csv"

df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(s3_path)
)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write \
  .mode("overwrite") \
  .saveAsTable("finance_analytics.statistics")
