# %%
s3_path = "s3://travel-analytics-bronze/mutualfund_etfs/dim_bonds/bonds.csv"

df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(s3_path)
)

df.display()

# %%
df.write \
  .mode("overwrite") \
  .saveAsTable("finance_analytics.databricks/bonds")
